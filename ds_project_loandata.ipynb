# %%
import pandas as pd

# %%
df = pd.read_excel('/content/loan_data.xlsx')
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0              22        female           Master          71948
# 1              21        female      High School          12282
# 2              25        female      High School          12438
# 3              23        female         Bachelor          79753
# 4              24          male           Master          66135
# ...           ...           ...              ...            ...
# 44995          27          male        Associate          47971
# 44996          37        female        Associate          65800
# 44997          33          male        Associate          56942
# 44998          29          male         Bachelor          33164
# 44999          24          male      High School          51609
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT      35000           PERSONAL
# 1                   0                   OWN       1000          EDUCATION
# 2                   3              MORTGAGE       5500            MEDICAL
# 3                   0                  RENT      35000            MEDICAL
# 4                   1                  RENT      35000            MEDICAL
# ...               ...                   ...        ...                ...
# 44995               6                  RENT      15000            MEDICAL
# 44996              17                  RENT       9000    HOMEIMPROVEMENT
# 44997               7                  RENT       2771  DEBTCONSOLIDATION
# 44998               4                  RENT      12000          EDUCATION
# 44999               1                  RENT       6665  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0              16.02                 0.49                           3
# 1              11.14                 0.08                           2
# 2              12.87                 0.44                           3
# 3              15.23                 0.44                           2
# 4              14.27                 0.53                           4
# ...              ...                  ...                         ...
# 44995          15.66                 0.31                           3
# 44996          14.07                 0.14                          11
# 44997          10.02                 0.05                          10
# 44998          13.23                 0.36                           6
# 44999          17.05                 0.13                           3
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 0               561                             No            1
# 1               504                            Yes            0
# 2               635                             No            1
# 3               675                             No            1
# 4               586                             No            1
# ...             ...                            ...          ...
# 44995           645                             No            1
# 44996           621                             No            1
# 44997           668                             No            1
# 44998           604                             No            1
# 44999           628                             No            1
#
# [45000 rows x 14 columns]

# %%
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0          22        female           Master          71948               0
# 1          21        female      High School          12282               0
# 2          25        female      High School          12438               3
# 3          23        female         Bachelor          79753               0
# 4          24          male           Master          66135               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT      35000    PERSONAL          16.02
# 1                   OWN       1000   EDUCATION          11.14
# 2              MORTGAGE       5500     MEDICAL          12.87
# 3                  RENT      35000     MEDICAL          15.23
# 4                  RENT      35000     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                           3           561
# 1                 0.08                           2           504
# 2                 0.44                           3           635
# 3                 0.44                           2           675
# 4                 0.53                           4           586
#
#   previous_loan_defaults_on_file  loan_status
# 0                             No            1
# 1                            Yes            0
# 2                             No            1
# 3                             No            1
# 4                             No            1

# %%
df.columns
# Out:
# Index(['person_age', 'person_gender', 'person_education', 'person_income',
#        'person_emp_exp', 'person_home_ownership', 'loan_amnt', 'loan_intent',
#        'loan_int_rate', 'loan_percent_income', 'cb_person_cred_hist_length',
#        'credit_score', 'previous_loan_defaults_on_file', 'loan_status'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %%
df.value_counts()
# Out:
# person_age  person_gender  person_education  person_income  person_emp_exp  person_home_ownership  loan_amnt  loan_intent        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  credit_score  previous_loan_defaults_on_file  loan_status
# 144         male           Bachelor          300616         125             RENT                   4800       VENTURE            13.57          0.02                 3                           789           No                              0              1
# 20          female         Associate         42674          0               RENT                   7000       MEDICAL            13.61          0.16                 2                           636           Yes                             0              1
#                                              104214         0               MORTGAGE               12000      DEBTCONSOLIDATION  8.49           0.12                 2                           641           Yes                             0              1
#                            High School       51391          0               RENT                   6500       VENTURE            11.71          0.13                 2                           630           No                              0              1
#                                              162939         0               MORTGAGE               15000      VENTURE            15.96          0.09                 2                           640           Yes                             0              1
#                                                                                                                                                                                                                                                              ..
#             male           Bachelor          93288          0               MORTGAGE               6000       VENTURE            8.00           0.06                 2                           699           Yes                             0              1
#                                              78039          0               RENT                   16000      VENTURE            15.31          0.21                 4                           671           No                              1              1
#                            Associate         226622         0               MORTGAGE               2000       EDUCATION          8.59           0.01                 4                           687           Yes                             0              1
#                                              78989          0               MORTGAGE               4800       VENTURE            9.99           0.06                 4                           678           No                              0              1
#                                              78837          0               MORTGAGE               4800       EDUCATION          9.99           0.06                 2                           598           Yes                             0              1
# Name: count, Length: 45000, dtype: int64

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# 25%         8.590000             0.070000                    3.000000
# 50%        11.010000             0.120000                    4.000000
# 75%        12.990000             0.190000                    8.000000
# max        20.000000             0.660000                   30.000000
#
#        credit_score   loan_status
# count  45000.000000  45000.000000
# mean     632.608756      0.222222
# std       50.435865      0.415744
# min      390.000000      0.000000
# 25%      601.000000      0.000000
# 50%      640.000000      0.000000
# 75%      670.000000      0.000000
# max      850.000000      1.000000

# %%
df.dtypes
# Out:
# person_age                          int64
# person_gender                      object
# person_education                   object
# person_income                       int64
# person_emp_exp                      int64
# person_home_ownership              object
# loan_amnt                           int64
# loan_intent                        object
# loan_int_rate                     float64
# loan_percent_income               float64
# cb_person_cred_hist_length          int64
# credit_score                        int64
# previous_loan_defaults_on_file     object
# loan_status                         int64
# dtype: object

# %%
df.drop(["person_education"],axis=1,inplace=True)

# %%
df
# Out:
#        person_age person_gender  person_income  person_emp_exp  \
# 0              22        female          71948               0
# 1              21        female          12282               0
# 2              25        female          12438               3
# 3              23        female          79753               0
# 4              24          male          66135               1
# ...           ...           ...            ...             ...
# 44995          27          male          47971               6
# 44996          37        female          65800              17
# 44997          33          male          56942               7
# 44998          29          male          33164               4
# 44999          24          male          51609               1
#
#       person_home_ownership  loan_amnt        loan_intent  loan_int_rate  \
# 0                      RENT      35000           PERSONAL          16.02
# 1                       OWN       1000          EDUCATION          11.14
# 2                  MORTGAGE       5500            MEDICAL          12.87
# 3                      RENT      35000            MEDICAL          15.23
# 4                      RENT      35000            MEDICAL          14.27
# ...                     ...        ...                ...            ...
# 44995                  RENT      15000            MEDICAL          15.66
# 44996                  RENT       9000    HOMEIMPROVEMENT          14.07
# 44997                  RENT       2771  DEBTCONSOLIDATION          10.02
# 44998                  RENT      12000          EDUCATION          13.23
# 44999                  RENT       6665  DEBTCONSOLIDATION          17.05
#
#        loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                     0.49                           3           561
# 1                     0.08                           2           504
# 2                     0.44                           3           635
# 3                     0.44                           2           675
# 4                     0.53                           4           586
# ...                    ...                         ...           ...
# 44995                 0.31                           3           645
# 44996                 0.14                          11           621
# 44997                 0.05                          10           668
# 44998                 0.36                           6           604
# 44999                 0.13                           3           628
#
#       previous_loan_defaults_on_file  loan_status
# 0                                 No            1
# 1                                Yes            0
# 2                                 No            1
# 3                                 No            1
# 4                                 No            1
# ...                              ...          ...
# 44995                             No            1
# 44996                             No            1
# 44997                             No            1
# 44998                             No            1
# 44999                             No            1
#
# [45000 rows x 13 columns]

# %%
# EDA - Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
df['loan_status'].value_counts().plot(kind='bar')
plt.title("Loan Status Distribution")
plt.xlabel("Loan Status")
plt.ylabel("Count")
plt.show()

# %%
print("\nMissing Values (%):\n", df.isnull().mean() * 100)
# Out:
# Missing Values (%):
#  person_age                        0.0
# person_gender                     0.0
# person_income                     0.0
# person_emp_exp                    0.0
# person_home_ownership             0.0
# loan_amnt                         0.0
# loan_intent                       0.0
# loan_int_rate                     0.0
# loan_percent_income               0.0
# cb_person_cred_hist_length        0.0
# credit_score                      0.0
# previous_loan_defaults_on_file    0.0
# loan_status                       0.0
# dtype: float64

# %%
num_cols = ['person_income', 'person_emp_exp', 'loan_amnt']

for col in num_cols:
    plt.hist(df[col].dropna(), bins=30)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
for col in num_cols:
    plt.boxplot(df[col].dropna())
    plt.title(f"Boxplot of {col}")
    plt.ylabel(col)
    plt.show()

# %%
pd.crosstab(df['credit_score'], df['loan_status']).plot(kind='bar')
plt.title("Credit History vs Loan Status")
plt.xlabel("Credit History")
plt.ylabel("Count")
plt.show()

# %%
corr = df[num_cols].corr()
print("\nCorrelation Matrix:\n", corr)
# Out:
# Correlation Matrix:
#                  person_income  person_emp_exp  loan_amnt
# person_income        1.000000        0.185987   0.242290
# person_emp_exp       0.185987        1.000000   0.044589
# loan_amnt            0.242290        0.044589   1.000000

# %%
df['person_gender'] = df['person_gender'].replace({
    'male': 'Male',
    'm': 'Male',
    'female': 'Female',
    'f': 'Female'
})

# %%
#encoding:

# %%
df["person_gender"]=df["person_gender"].map({"Male":0,"Female":1})

# %%
df.dtypes
# Out:
# person_age                          int64
# person_gender                       int64
# person_income                       int64
# person_emp_exp                      int64
# person_home_ownership              object
# loan_amnt                           int64
# loan_intent                        object
# loan_int_rate                     float64
# loan_percent_income               float64
# cb_person_cred_hist_length          int64
# credit_score                        int64
# previous_loan_defaults_on_file     object
# loan_status                         int64
# dtype: object

# %%
df['person_home_ownership'].value_counts()
# Out:
# person_home_ownership
# RENT        23443
# MORTGAGE    18489
# OWN          2951
# OTHER         117
# Name: count, dtype: int64

# %%
df["person_home_ownership"]=df["person_home_ownership"].map({"RENT":0,"MORTGAGE":1,"OWN":2,"OTHER":3})

# %%
df.dtypes
# Out:
# person_age                          int64
# person_gender                       int64
# person_income                       int64
# person_emp_exp                      int64
# person_home_ownership               int64
# loan_amnt                           int64
# loan_intent                        object
# loan_int_rate                     float64
# loan_percent_income               float64
# cb_person_cred_hist_length          int64
# credit_score                        int64
# previous_loan_defaults_on_file     object
# loan_status                         int64
# dtype: object

# %%
df['loan_intent'].value_counts()
# Out:
# loan_intent
# EDUCATION            9153
# MEDICAL              8548
# VENTURE              7819
# PERSONAL             7552
# DEBTCONSOLIDATION    7145
# HOMEIMPROVEMENT      4783
# Name: count, dtype: int64

# %%
df["loan_intent"]=df["loan_intent"].map({"EDUCATION":0,"MEDICAL":1,"VENTURE":2,"PERSONAL":3,"DEBTCONSOLIDATION":4,"HOMEIMPROVEMENT":5})

# %%
df
# Out:
#        person_age  person_gender  person_income  person_emp_exp  \
# 0              22              1          71948               0
# 1              21              1          12282               0
# 2              25              1          12438               3
# 3              23              1          79753               0
# 4              24              0          66135               1
# ...           ...            ...            ...             ...
# 44995          27              0          47971               6
# 44996          37              1          65800              17
# 44997          33              0          56942               7
# 44998          29              0          33164               4
# 44999          24              0          51609               1
#
#        person_home_ownership  loan_amnt  loan_intent  loan_int_rate  \
# 0                          0      35000            3          16.02
# 1                          2       1000            0          11.14
# 2                          1       5500            1          12.87
# 3                          0      35000            1          15.23
# 4                          0      35000            1          14.27
# ...                      ...        ...          ...            ...
# 44995                      0      15000            1          15.66
# 44996                      0       9000            5          14.07
# 44997                      0       2771            4          10.02
# 44998                      0      12000            0          13.23
# 44999                      0       6665            4          17.05
#
#        loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                     0.49                           3           561
# 1                     0.08                           2           504
# 2                     0.44                           3           635
# 3                     0.44                           2           675
# 4                     0.53                           4           586
# ...                    ...                         ...           ...
# 44995                 0.31                           3           645
# 44996                 0.14                          11           621
# 44997                 0.05                          10           668
# 44998                 0.36                           6           604
# 44999                 0.13                           3           628
#
#       previous_loan_defaults_on_file  loan_status
# 0                                 No            1
# 1                                Yes            0
# 2                                 No            1
# 3                                 No            1
# 4                                 No            1
# ...                              ...          ...
# 44995                             No            1
# 44996                             No            1
# 44997                             No            1
# 44998                             No            1
# 44999                             No            1
#
# [45000 rows x 13 columns]

# %%
df.dtypes
# Out:
# person_age                          int64
# person_gender                       int64
# person_income                       int64
# person_emp_exp                      int64
# person_home_ownership               int64
# loan_amnt                           int64
# loan_intent                         int64
# loan_int_rate                     float64
# loan_percent_income               float64
# cb_person_cred_hist_length          int64
# credit_score                        int64
# previous_loan_defaults_on_file     object
# loan_status                         int64
# dtype: object

# %%
df['previous_loan_defaults_on_file'].value_counts()
# Out:
# previous_loan_defaults_on_file
# Yes    22858
# No     22142
# Name: count, dtype: int64

# %%
df["previous_loan_defaults_on_file"]=df["previous_loan_defaults_on_file"].map({"Yes":0,"No":1})

# %%
df.head()
# Out:
#    person_age  person_gender  person_income  person_emp_exp  \
# 0          22              1          71948               0
# 1          21              1          12282               0
# 2          25              1          12438               3
# 3          23              1          79753               0
# 4          24              0          66135               1
#
#    person_home_ownership  loan_amnt  loan_intent  loan_int_rate  \
# 0                      0      35000            3          16.02
# 1                      2       1000            0          11.14
# 2                      1       5500            1          12.87
# 3                      0      35000            1          15.23
# 4                      0      35000            1          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                           3           561
# 1                 0.08                           2           504
# 2                 0.44                           3           635
# 3                 0.44                           2           675
# 4                 0.53                           4           586
#
#    previous_loan_defaults_on_file  loan_status
# 0                               1            1
# 1                               0            0
# 2                               1            1
# 3                               1            1
# 4                               1            1

# %%
X=df.iloc[:,1:-1]
X.head()
# Out:
#    person_gender  person_income  person_emp_exp  person_home_ownership  \
# 0              1          71948               0                      0
# 1              1          12282               0                      2
# 2              1          12438               3                      1
# 3              1          79753               0                      0
# 4              0          66135               1                      0
#
#    loan_amnt  loan_intent  loan_int_rate  loan_percent_income  \
# 0      35000            3          16.02                 0.49
# 1       1000            0          11.14                 0.08
# 2       5500            1          12.87                 0.44
# 3      35000            1          15.23                 0.44
# 4      35000            1          14.27                 0.53
#
#    cb_person_cred_hist_length  credit_score  previous_loan_defaults_on_file
# 0                           3           561                               1
# 1                           2           504                               0
# 2                           3           635                               1
# 3                           2           675                               1
# 4                           4           586                               1

# %%
y=df.iloc[:,-1]
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    1
# Name: loan_status, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)
X_scaled
# Out:
# array([[ 1.11006918, -0.10408961, -0.89228413, ..., -0.73910854,
#         -1.41981408,  1.01603973],
#        [ 1.11006918, -0.84600467, -0.89228413, ..., -0.99686317,
#         -2.5499748 , -0.98421348],
#        [ 1.11006918, -0.84406489, -0.3975175 , ..., -0.73910854,
#          0.04741211,  1.01603973],
#        ...,
#        [-0.90084476, -0.29068126,  0.26217134, ...,  1.06517387,
#          0.70171569,  1.01603973],
#        [-0.90084476, -0.58634807, -0.23259529, ...,  0.03415535,
#         -0.5672367 ,  1.01603973],
#        [-0.90084476, -0.35699428, -0.72736192, ..., -0.73910854,
#         -0.09137955,  1.01603973]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.3,random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(),
    "KNN": KNeighborsClassifier(),
    "SVM": SVC()
}

# %%
from sklearn.metrics import accuracy_score

results = {}

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    results[name] = acc
    print(f"{name}: {acc:.4f}")
# Out:
# Logistic Regression: 0.8907
# Decision Tree: 0.8946
# Random Forest: 0.9271
# KNN: 0.8930
# SVM: 0.9075

# %%
import pandas as pd

results_df = pd.DataFrame(
    results.items(),
    columns=["Model", "Accuracy"]
).sort_values(by="Accuracy", ascending=False)

results_df
# Out:
#                  Model  Accuracy
# 2        Random Forest  0.927111
# 4                  SVM  0.907481
# 1        Decision Tree  0.894593
# 3                  KNN  0.893037
# 0  Logistic Regression  0.890741

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=50)
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=50)

# %%
y_pred=rf.predict(X_test)
y_pred
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95     10421
#            1       0.89      0.77      0.82      3079
#
#     accuracy                           0.92     13500
#    macro avg       0.91      0.87      0.89     13500
# weighted avg       0.92      0.92      0.92     13500

# %%
y_new=rf.predict(scaler.transform([[0,71948,0,0,35000,3,16.02,0.49,3,561,0]]))
y_new
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([0])

# %%
import joblib
# Save model
joblib.dump(rf, "random_forest_model.save")
# Out:
# ['random_forest_model.save']

# %%
# Load model
model = joblib.load("random_forest_model.save")

# %%
# Predict
model.predict(X_test)
# Out:
# array([0, 0, 1, ..., 0, 0, 0])
